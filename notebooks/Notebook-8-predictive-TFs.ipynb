# %%
import wot

# %% [markdown]
# # Notebook 8: Predictive Transcription Factors

# %%
FULL_DS_PATH = 'data/ExprMatrix.h5ad'
CELL_DAYS_PATH = 'data/cell_days.txt'
CELL_SETS_PATH = 'data/major_cell_sets.gmt'
TFS_PATH = 'data/TFs.txt'

# Load expression dataset and subset to transcription factors
adata = wot.io.read_dataset(FULL_DS_PATH, obs=[CELL_DAYS_PATH], var_filter=TFS_PATH)
# Load transport map model and cell sets
tmap_model = wot.tmap.TransportMapModel.from_directory('tmaps/serum')
cell_sets = wot.io.read_sets('data/major_cell_sets.gmt', as_dict=True)
# create indicator vector IPS for cell set at day 17
target_destinations = tmap_model.population_from_cell_sets({'IPS':cell_sets['IPS']}, at_time=17)

# %%
# Compute fate matrix for IPS 
fate_ds = tmap_model.fates(target_destinations)

# %%
# Find differentially expressed genes
results = wot.tmap.diff_exp(adata[adata.obs['day']==14.0], fate_ds,  nperm=1000)

# %%
df = results['IPS_Other']
df.sort_values('fraction_expressed_ratio_14.0_14.0', inplace=True, ascending=False)
df.head(10)
# Out:
#          mean_IPS_14.0  fraction_expressed_IPS_14.0  mean_Other_14.0  \
# index
# Nanog         1.269970                     0.906913         0.008572
# Mybl2         1.227467                     0.912747         0.066180
# Sox2          0.955528                     0.835184         0.031326
# Cdc5l         1.104749                     0.915850         0.307593
# Zfp42         0.742521                     0.801558         0.017675
# Trp53         1.173007                     0.942899         0.512222
# Tgif1         0.792694                     0.814696         0.336901
# Tbx3          0.443686                     0.575048         0.042313
# Rest          0.769769                     0.846633         0.374104
# Klf2          0.438051                     0.591346         0.046394
# Mycn          0.437508                     0.577741         0.056018
# Klf4          0.520977                     0.604626         0.140407
# Etv5          0.447895                     0.575368         0.084293
# Ybx1          1.353101                     0.954758         0.995845
# Esrrb         0.360088                     0.528240         0.006861
# Sox15         0.358219                     0.514965         0.037643
# Hesx1         0.314649                     0.414110         0.002163
# Dnajc21       0.398727                     0.562235         0.091142
# E2f4          0.543986                     0.703487         0.271497
# Klf5          0.366700                     0.522406         0.098963
# Klf9          0.520124                     0.700731         0.252787
# Sp2           0.320766                     0.502666         0.068967
# Elf3          0.402169                     0.507764         0.153921
# Smarcc1       0.685123                     0.788519         0.473734
# Ctcf          0.409170                     0.593432         0.208448
# Msc           0.198630                     0.278728         0.001331
# Rbpj          0.600024                     0.696831         0.406258
# Erf           0.416342                     0.569905         0.239723
# Otx2          0.188465                     0.259201         0.012249
# Rfx2          0.168247                     0.293900         0.008140
# ...                ...                          ...              ...
# Mbtps2        0.184368                     0.302951         0.113730
# Dmrt1         0.063820                     0.121093         0.000314
# Tbp           0.141851                     0.253718         0.080048
# Sox13         0.086351                     0.159826         0.031689
# Tcf7          0.076891                     0.124535         0.022337
# Hhex          0.069443                     0.121654         0.017429
# Lef1          0.053038                     0.080729         0.009028
# Gli2          0.061749                     0.111123         0.019391
# Klf8          0.056512                     0.100584         0.017008
# Hmga1         0.055555                     0.097517         0.016704
# Etv2          0.038367                     0.070096         0.002294
# Olig2         0.032745                     0.064099         0.000066
# Gbx2          0.031857                     0.057658         0.004548
# Ybx2          0.031302                     0.058772         0.004028
# Klf15         0.030718                     0.055123         0.004075
# Pou4f1        0.025347                     0.039274         0.000852
# Foxd3         0.022858                     0.034800         0.000250
# Mlxipl        0.022312                     0.043597         0.001526
# Eomes         0.021177                     0.041448         0.000696
# En2           0.017195                     0.033637         0.000303
# Hoxb13        0.015321                     0.027665         0.000218
# Tcf15         0.015640                     0.029262         0.000733
# Stat4         0.011926                     0.023379         0.000723
# Sox30         0.012357                     0.023412         0.001659
# Hnf1a         0.009037                     0.017672         0.000298
# Nr1i3         0.008703                     0.017032         0.000313
# Hnf4a         0.007908                     0.011650         0.000016
# Gcm2          0.003219                     0.005826         0.000007
# Lhx3          0.002988                     0.005853         0.000005
# Pitx3         0.002983                     0.005846         0.000006
#
#          fraction_expressed_Other_14.0  fold_change_14.0_14.0  \
# index
# Nanog                         0.009727               1.261397
# Mybl2                         0.093497               1.161286
# Sox2                          0.035825               0.924202
# Cdc5l                         0.388319               0.797156
# Zfp42                         0.025676               0.724846
# Trp53                         0.526216               0.660785
# Tgif1                         0.376528               0.455793
# Tbx3                          0.054122               0.401373
# Rest                          0.441295               0.395664
# Klf2                          0.063116               0.391656
# Mycn                          0.072364               0.381491
# Klf4                          0.161015               0.380570
# Etv5                          0.111430               0.363602
# Ybx1                          0.780567               0.357256
# Esrrb                         0.009513               0.353227
# Sox15                         0.055200               0.320576
# Hesx1                         0.003324               0.312486
# Dnajc21                       0.137631               0.307585
# E2f4                          0.350169               0.272489
# Klf5                          0.134166               0.267737
# Klf9                          0.296311               0.267338
# Sp2                           0.101676               0.251798
# Elf3                          0.165723               0.248248
# Smarcc1                       0.530772               0.211389
# Ctcf                          0.285635               0.200722
# Msc                           0.001723               0.197299
# Rbpj                          0.440354               0.193766
# Erf                           0.307581               0.176619
# Otx2                          0.013747               0.176217
# Rfx2                          0.012438               0.160106
# ...                                ...                    ...
# Mbtps2                        0.159785               0.070638
# Dmrt1                         0.000584               0.063505
# Tbp                           0.121409               0.061804
# Sox13                         0.049179               0.054663
# Tcf7                          0.034654               0.054554
# Hhex                          0.020594               0.052015
# Lef1                          0.012169               0.044011
# Gli2                          0.029423               0.042359
# Klf8                          0.027679               0.039504
# Hmga1                         0.026706               0.038851
# Etv2                          0.002360               0.036073
# Olig2                         0.000130               0.032679
# Gbx2                          0.006546               0.027309
# Ybx2                          0.005660               0.027274
# Klf15                         0.005549               0.026643
# Pou4f1                        0.001543               0.024495
# Foxd3                         0.000356               0.022608
# Mlxipl                        0.002180               0.020786
# Eomes                         0.001165               0.020481
# En2                           0.000410               0.016892
# Hoxb13                        0.000404               0.015103
# Tcf15                         0.001166               0.014907
# Stat4                         0.001157               0.011203
# Sox30                         0.003103               0.010698
# Hnf1a                         0.000583               0.008740
# Nr1i3                         0.000612               0.008390
# Hnf4a                         0.000024               0.007892
# Gcm2                          0.000012               0.003212
# Lhx3                          0.000011               0.002982
# Pitx3                         0.000011               0.002977
#
#          p_value_14.0_14.0  fdr_14.0_14.0  k_14.0_14.0
# index
# Nanog                  0.0            0.0          0.0
# Mybl2                  0.0            0.0          0.0
# Sox2                   0.0            0.0          0.0
# Cdc5l                  0.0            0.0          0.0
# Zfp42                  0.0            0.0          0.0
# Trp53                  0.0            0.0          0.0
# Tgif1                  0.0            0.0          0.0
# Tbx3                   0.0            0.0          0.0
# Rest                   0.0            0.0          0.0
# Klf2                   0.0            0.0          0.0
# Mycn                   0.0            0.0          0.0
# Klf4                   0.0            0.0          0.0
# Etv5                   0.0            0.0          0.0
# Ybx1                   0.0            0.0          0.0
# Esrrb                  0.0            0.0          0.0
# Sox15                  0.0            0.0          0.0
# Hesx1                  0.0            0.0          0.0
# Dnajc21                0.0            0.0          0.0
# E2f4                   0.0            0.0          0.0
# Klf5                   0.0            0.0          0.0
# Klf9                   0.0            0.0          0.0
# Sp2                    0.0            0.0          0.0
# Elf3                   0.0            0.0          0.0
# Smarcc1                0.0            0.0          0.0
# Ctcf                   0.0            0.0          0.0
# Msc                    0.0            0.0          0.0
# Rbpj                   0.0            0.0          0.0
# Erf                    0.0            0.0          0.0
# Otx2                   0.0            0.0          0.0
# Rfx2                   0.0            0.0          0.0
# ...                    ...            ...          ...
# Mbtps2                 0.0            0.0          0.0
# Dmrt1                  0.0            0.0          0.0
# Tbp                    0.0            0.0          0.0
# Sox13                  0.0            0.0          0.0
# Tcf7                   0.0            0.0          0.0
# Hhex                   0.0            0.0          0.0
# Lef1                   0.0            0.0          0.0
# Gli2                   0.0            0.0          0.0
# Klf8                   0.0            0.0          0.0
# Hmga1                  0.0            0.0          0.0
# Etv2                   0.0            0.0          0.0
# Olig2                  0.0            0.0          0.0
# Gbx2                   0.0            0.0          0.0
# Ybx2                   0.0            0.0          0.0
# Klf15                  0.0            0.0          0.0
# Pou4f1                 0.0            0.0          0.0
# Foxd3                  0.0            0.0          0.0
# Mlxipl                 0.0            0.0          0.0
# Eomes                  0.0            0.0          0.0
# En2                    0.0            0.0          0.0
# Hoxb13                 0.0            0.0          0.0
# Tcf15                  0.0            0.0          0.0
# Stat4                  0.0            0.0          0.0
# Sox30                  0.0            0.0          0.0
# Hnf1a                  0.0            0.0          0.0
# Nr1i3                  0.0            0.0          0.0
# Hnf4a                  0.0            0.0          0.0
# Gcm2                   0.0            0.0          0.0
# Lhx3                   0.0            0.0          0.0
# Pitx3                  0.0            0.0          0.0
#
# [77 rows x 8 columns]

# %% [markdown]
# We can run the previous functions from the command line using the commands:

# %% [markdown]
# ```wot fates \
# --tmap tmaps/serum \
# --cell_set data/major_cell_sets.gmt \
# --day 17 \
# --cell_set_filter IPS \
# --out IPS \
# --verbose```

# %% [markdown]
# ```wot diff_exp \
# --matrix data/ExprMatrix.h5ad \
# --cell_days data/cell_days.txt \
# --fates IPS_fates.txt \
# --nperm 1000 \
# --gene_filter data/TFs.txt \
# --cell_day_filter 14 \
# --verbose```
